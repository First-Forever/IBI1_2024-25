# %%
#import necessary libraries
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

#Read in the csv file
dalys_data = pd.read_csv('dalys-rate-from-all-causes.csv')

#Show the third column (the year) for the first 10 rows (inclusive)
print("The third column (the year) for the first 10 rows:")            
print(dalys_data.loc[:9,'Year'])

#Shown the 10th year
print(f"\nThe 10th year with DALYs data recorded in Afghanistan: {dalys_data[dalys_data['Entity'] == 'Afghanistan'].at[9, 'DALYs']}")

#The DALYs for countries in 1990:
print('\nDALYs for all countries in 1990:')
print(dalys_data[dalys_data['Year'] == 1990][['Entity', 'DALYs']])

#Show the mean value of DALYs in the UK and France
UK_mean_DALY = dalys_data[dalys_data["Entity"] == 'United Kingdom']['DALYs'].mean()
France_mean_DALY = dalys_data[dalys_data["Entity"] == 'France']['DALYs'].mean()         #Extract the DALYs values and calculate their means
print(f'\nMean DALYs in the UK (rounded to a 2 point scale): {UK_mean_DALY:.2f}')
print(f'Mean DALYs in France (rounded to a 2 point scale): {France_mean_DALY:.2f}')     #Print their values
if UK_mean_DALY > France_mean_DALY:
    print('DALYs mean in the UK is larger than France.')
elif UK_mean_DALY == France_mean_DALY:
    print('The DALYs means in the UK and France are the same.')
else:
    print('DALYs mean in the UK is less than France.')

#Plot the change of DALYs in the UK
df_UK = dalys_data[dalys_data["Entity"] == 'United Kingdom'].sort_values('Year')        #First sort the series according to values in the 'Year' column
plt.figure(figsize = (10, 6))                                                           #Plot the figure
plt.plot(df_UK['Year'], df_UK['DALYs'])
plt.xlabel('Year')
plt.ylabel('Disability-Adjusted Life Years (DALYs) in the UK')
plt.title('Trends in Disability-Adjusted Life Years (DALYs) in the United Kingdom over Time')
plt.show()

#Find all countries with a less than 20000 DALYs in a certain year
print('The countries that have less than 20000 DALYs in a certain year:')
print(dalys_data[dalys_data['DALYs'] <= 20000])
# Out:
# The third column (the year) for the first 10 rows:
# 0    1990
# 1    1991
# 2    1992
# 3    1993
# 4    1994
# 5    1995
# 6    1996
# 7    1997
# 8    1998
# 9    1999
# Name: Year, dtype: int64
#
# The 10th year with DALYs data recorded in Afghanistan: 82624.94
#
# DALYs for all countries in 1990:
#                               Entity     DALYs
# 0                        Afghanistan  86375.17
# 30              African Region (WHO)  81293.92
# 60                           Albania  32964.61
# 90                           Algeria  44481.53
# 120                   American Samoa  35230.49
# ...                              ...       ...
# 6690  World Bank Lower Middle Income  61774.10
# 6720  World Bank Upper Middle Income  41087.86
# 6750                           Yemen  67015.90
# 6780                          Zambia  90310.81
# 6810                        Zimbabwe  55804.06
#
# [228 rows x 2 columns]
#
# Mean DALYs in the UK (rounded to a 2 point scale): 23319.02
# Mean DALYs in France (rounded to a 2 point scale): 21474.63
# DALYs mean in the UK is larger than France.
# The countries that have less than 20000 DALYs in a certain year:
#            Entity Code  Year     DALYs
# 164       Andorra  AND  2004  19986.44
# 165       Andorra  AND  2005  19900.29
# 166       Andorra  AND  2006  19820.48
# 167       Andorra  AND  2007  19715.22
# 168       Andorra  AND  2008  19579.23
# ...           ...  ...   ...       ...
# 5819  Switzerland  CHE  2019  17635.03
# 5875       Taiwan  TWN  2015  19891.75
# 5877       Taiwan  TWN  2017  19936.04
# 5878       Taiwan  TWN  2018  19899.19
# 5879       Taiwan  TWN  2019  19702.97
#
# [294 rows x 4 columns]

# %%
dalys_data['Year'] == 1990
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6835    False
# 6836    False
# 6837    False
# 6838    False
# 6839    False
# Name: Year, Length: 6840, dtype: bool
